# %% [markdown]
# <a href="https://colab.research.google.com/github/KatrinRosenthal/CFPS-calculator/blob/main/Copy_of_megellan_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Workflow for kinetic parameter estimation
#
# This notebook contains a workflow for kinetic parameter estimation based on photometric raw data.
# In the next cell, `MTPHandler` and `EnzymePynetics` are installed and imported.
# Occasionally, Colab has an issue with the import. In this case got to `Runtime` and click `Restart runtime`. Then execute the cell again.

# %%
import sys

try:
    from MTPHandler.core.plate import Plate
    from MTPHandler.core.reactant import Reactant
    from MTPHandler.core.protein import Protein
    from MTPHandler.ioutils import parse_magellan

except ModuleNotFoundError:
    # !{sys.executable} -m pip install git+https://github.com/FAIRChemistry/MTPHandler.git@ci --quiet
    # !git clone https://github.com/haeussma/laccase_kinetics.git
    from MTPHandler.core.plate import Plate
    from MTPHandler.core.reactant import Reactant
    from MTPHandler.core.protein import Protein
    from MTPHandler.ioutils import parse_magellan

# %% [markdown]
# ## Load experimental data
#
# In the following cell, the Magellan output file is read in and the data is mapped to the `Plate` object.

# %%
# Path to spectrometer output file
path = "laccase_kinetics/laccase_kinetics/Laccase_kinetic_woTween_Rawdata.xlsx"

# Load plate
plate = Plate.from_reader(
    reader=parse_magellan,
    path=path,
    ph=3,
    wavelength=420,
)

# %%
# Visualize plate data
plate.visualize()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="04f23e3e-94b3-4bbf-84de-67f4f933f1c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04f23e3e-94b3-4bbf-84de-67f4f933f1c3")) {                    Plotly.newPlot(                        "04f23e3e-94b3-4bbf-84de-67f4f933f1c3",                        [{"line":{"color":"#636EFA"},"name":"420.0 nm","showlegend":false,"x":[0.0,49.0,97.0,146.0,194.0,242.0,291.0,340.0,388.0,436.0,485.0,533.0,581.0,630.0,679.0,727.0,776.0,824.0,872.0,928.0],"y":[-0.0454,-0.0401,-0.0353,-0.0335,-0.0315,-0.0302,-0.0275,-0.0259,-0.0245,-0.0244,-0.0242,-0.0258,-0.026,-0.0252,-0.0253,-0.0258,-0.0264,-0.0261,-0.0259,-0.027],"type":"scatter","xaxis":"x","yaxis":"y","hovertemplate":"%{y:.2f}"},{"line":{"color":"#636EFA"},"name":"420.0 nm","showlegend":false,"x":[0.0,49.0,97.0,146.0,194.0,242.0,291.0,340.0,388.0,436.0,485.0,533.0,581.0,630.0,679.0,727.0,776.0,824.0,872.0,928.0],"y":[0.0141,0.0592,0.0996,0.1438,0.1908,0.2399,0.291,0.3422,0.3971,0.4518,0.5085,0.5657,0.6247,0.6859,0.7452,0.8081,0.8709,0.9325,0.9959,1.0601],"type":"scatter","xaxis":"x2","yaxis":"y2","hovertemplate":"%{y:.2f}"},{"line":{"color":"#636EFA"},"name":"420.0 nm","showlegend":false,"x":[0.0,49.0,97.0,146.0,194.0,242.0,291.0,340.0,388.0,436.0,485.0,533.0,581.0,630.0,679.0,727.0,776.0,824.0,872.0,928.0],"y":[0.0251,0.0679,0.1082,0.1561,0.2059,0.2601,0.3147,0.371,0.4322,0.4944,0.56,0.625,0.6935,0.7648,0.8349,0.9097,0.9865,1.0612,1.1384,1.2173],"type":"scatter","xaxis":"x3","yaxis":"y3","hovertemplate":"%{y:.2f}"},{"line":{"color":"#636EFA"},"name":"420.0 nm","showlegend":false,"x":[0.0,49.0,97.0,146.0,194.0,242.0,291.0,340.0,388.0,436.0,485.0,533.0,581.0,630.0,679.0,727.0,776.0,824.0,872.0,928.0],"y":[0.0268,0.0716,0.1193,0.1694,0.2238,0.2828,0.344,0.4072,0.4745,0.5432,0.6141,0.6896,0.7638,0.842,0.9212,1.0038,1.0877,1.1705,1.2579,1.3446],"type":"scatter","xaxis":"x4","yaxis":"y4","hovertemplate":"%{y:.2f}"},{"line":{"color":"#636EFA"},"name":"420.0 nm","showlegend":false,"x":[0.0,49.0,97.0,146.0,194.0,242.0,291.0,340.0,388.0,436.0,485.0,533.0,581.0,630.0,679.0,727.0,776.0,824.0,872.0,928.0],"y":[0.0739,0.1267,0.1837,0.2459,0.3123,0.3854,0.4633,0.5456,0.6323,0.7222,0.8143,0.9117,1.0116,1.1146,1.2199,1.3294,1.4369,1.5488,1.6607,1.7743],"type":"scatter","xaxis":"x5","yaxis":"y5","hovertemplate":"%{y:.2f}"},{"line":{"color":"#636EFA"},"name":"420.0 nm","showlegend":false,"x":[0.0,49.0,97.0,146.0,194.0,242.0,291.0,340.0,388.0,436.0,485.0,533.0,581.0,630.0,679.0,727.0,776.0,824.0,872.0,928.0],"y":[0.3865,0.4429,0.5135,0.5897,0.674,0.7662,0.8625,0.9621,1.0666,1.1727,1.2819,1.3921,1.5062,1.6193,1.7345,1.85,1.9671,2.0806,2.1916,2.3045],"type":"scatter","xaxis":"x7","yaxis":"y7","hovertemplate":"%{y:.2f}"},{"line":{"color":"#636EFA"},"name":"420.0 nm","showlegend":false,"x":[0.0,49.0,97.0,146.0,194.0,242.0,291.0,340.0,388.0,436.0,485.0,533.0,581.0,630.0,679.0,727.0,776.0,824.0,872.0,928.0],"y":[0.6291,0.6841,0.7521,0.8293,0.9149,1.0075,1.1048,1.2049,1.3092,1.4165,1.5245,1.6334,1.7434,1.8562,1.9684,2.0773,2.1878,2.2932,2.3973,2.4981],"type":"scatter","xaxis":"x8","yaxis":"y8","hovertemplate":"%{y:.2f}"},{"line":{"color":"#636EFA"},"name":"420.0 nm","showlegend":false,"x":[0.0,49.0,97.0,146.0,194.0,242.0,291.0,340.0,388.0,436.0,485.0,533.0,581.0,630.0,679.0,727.0,776.0,824.0,872.0,928.0],"y":[0.8783,0.9286,0.9942,1.0687,1.1511,1.2394,1.3348,1.4327,1.5349,1.6362,1.7413,1.8453,1.9526,2.0579,2.1636,2.266,2.3666,2.464,2.5557,2.6454],"type":"scatter","xaxis":"x9","yaxis":"y9","hovertemplate":"%{y:.2f}"},{"line":{"color":"#636EFA"},"name":"420.0 nm","showlegend":false,"x":[0.0,49.0,97.0,146.0,194.0,242.0,291.0,340.0,388.0,436.0,485.0,533.0,581.0,630.0,679.0,727.0,776.0,824.0,872.0,928.0],"y":[-0.0401, ...

# %% [markdown]
# ### Define reactants
#
# Next up, all involved reactants and proteins present in any of the MTP wells are defined.

# %%
buffer = plate.add_reactant(id="s0", name="Buffer", constant=True)

abts = plate.add_reactant(id="s1", name="ABTS", constant=False)

abts_radical = plate.add_reactant(id="s2", name="ABTS radical", constant=False)

laccase = plate.add_protein(
    id="p0", name="Laccase", constant=True, sequence="MSSKSKPKDVKV"
)

# %% [markdown]
# ### Assign initial conditions
#
# Species can be assigned to all wells, row-wise, or column-wise one species at a time. Thereby, multiple rows with identical initial concentrations can be assigned simultaneously.
# Please not that currently all units need to be of the same magnitude. Otherwise the later modeling results will not be correct.

# %%
# Assign buffer concentration
plate.assign_species(to="all", species=buffer,
                     init_conc=100, conc_unit="mmol / l")

# Assign substrate concentrations
plate.assign_species(
    to="rows",
    species=abts,
    ids=["A", "B", "C", "D"],
    init_conc=[0, 0.3, 0.6, 0.9, 5, 30, 50, 70],
    conc_unit="mmol / l",
)

plate.assign_species(
    to="rows",
    species=abts,
    ids=["E", "F", "G", "H"],
    init_conc=[0.15, 0.45, 0.75, 1, 10, 40, 60, 80],
    conc_unit="mmol / l",
)

plate.assign_species(to="all", species=abts_radical,
                     init_conc=0, conc_unit="mmol / l")


# Assign enzyme concentrations
plate.assign_species(to="all", species=laccase,
                     init_conc=0.006, conc_unit="mmol / l")
# Out:
# Assigned Buffer to all wells.
# Assigned ABTS with concentrations of [0, 0.3, 0.6, 0.9, 5, 30, 50, 70] mmol / l to row A.
# Assigned ABTS with concentrations of [0, 0.3, 0.6, 0.9, 5, 30, 50, 70] mmol / l to row B.
# Assigned ABTS with concentrations of [0, 0.3, 0.6, 0.9, 5, 30, 50, 70] mmol / l to row C.
# Assigned ABTS with concentrations of [0, 0.3, 0.6, 0.9, 5, 30, 50, 70] mmol / l to row D.
# Assigned ABTS with concentrations of [0.15, 0.45, 0.75, 1, 10, 40, 60, 80] mmol / l to row E.
# Assigned ABTS with concentrations of [0.15, 0.45, 0.75, 1, 10, 40, 60, 80] mmol / l to row F.
# Assigned ABTS with concentrations of [0.15, 0.45, 0.75, 1, 10, 40, 60, 80] mmol / l to row G.
# Assigned ABTS with concentrations of [0.15, 0.45, 0.75, 1, 10, 40, 60, 80] mmol / l to row H.
# Assigned ABTS radical to all wells.
# Assigned Laccase to all wells.

# %% [markdown]
# ### Create EnzymeML document

# %% [markdown]
# As the last part of data treatment, the `Plate` object is converted to an `EnzymeMLDocument` object. This object is the basis for all further processing steps.

# %%
enzymeml = plate.to_enzymeml(
    name="laccase kinetic assay",
    detected_reactant=abts_radical,
    wavelength=420,
    path="lac_kinetics.json",
    ignore_blank_status=True,
)
# Out:
# Found 64 catalyzed wells

# %% [markdown]
# ## Concentration calculation
#
# In this case I assume that the concentration should be calculated via the extinction coefficient for ABTS radical. Therefore, I've prepared quick methods for applying an extinction coefficient to the previously created `EnzymeMLDocument` object. The methods are defined in the next cell.

# %%
def calculate_concentration(absorptions, ext_coeff: float, pathlength: float):
    """Calculated concentrations for a list of absorption values,
    given an extinction coefficient and path length.
    """

    return [absorption / (ext_coeff * pathlength) for absorption in absorptions]


def apply_extinction_coef(enzymeml, ext_coeff: float, pathlength: float):
    """Applies extinction coefficient to all replicates in an EnzymeML document."""

    for measurement in enzymeml.measurements:
        for species in measurement.species:
            if not species.replicates:
                continue
            for replicate in species.replicates:
                replicate.data = calculate_concentration(
                    replicate.data, ext_coeff, pathlength
                )

# %% [markdown]
# I assumed an extinction coefficient of 36 $mM^{-1} cm^{-1}$ and path length of 0.4 $cm$ for ABTS radical. The extinction coefficient is applied to all wells containing ABTS radical. The resulting concentrations are stored in the `EnzymeMLDocument` object.

# %%
# Apply extinction coefficient to EnzymeML document
apply_extinction_coef(enzymeml=enzymeml, ext_coeff=36, pathlength=0.4)

# %% [markdown]
# ## Parameter estimation

# %%
try:
    from EnzymePynetics.core.estimator import Estimator

except ModuleNotFoundError:
    # !{sys.executable} -m pip install git+https://github.com/haeussma/EnzymePynetics.git@enzymeml-platform --quiet
    from EnzymePynetics.core.estimator import Estimator
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 89.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 25.7 MB/s eta 0:00:00
#   Building wheel for enzymepynetics (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.1.2 which is incompatible.

# %%
# Initialize estimator
estimator, _ = Estimator.from_enzymeml(enzymeml, abts_radical)

# %%
# Define reaction
oxidation = estimator.add_reaction(
    id="r1", name="Oxidation", educt=abts, product=abts_radical, enzyme=laccase
)

# %% [markdown]
# In the next cell, possible substrate rate laws are defined. Each rate law is fitted to the measurement data individually.

# %%
# Substrate rate laws
michaelis = estimator.add_model(
    id="model1",
    name="michaelis-menten",
    equation="substrate = -substrate * enzyme * k_cat / (K_m + substrate)",
)

competitive_product = estimator.add_model(
    id="model3",
    name="competitive product inhibition",
    equation="substrate = -substrate * enzyme * k_cat / (K_m * (1 + product / K_ic) + substrate)",
)

substrate_inhibition = estimator.add_model(
    id="model4",
    name="substrate inhibition",
    equation="substrate = -k_cat * enzyme * substrate / (K_m + ((1+(substrate/K_iu))*substrate))",
)

# %%
# Fit models
estimator.fit_models()
# Out:
# /usr/local/lib/python3.10/dist-packages/sdRDM/base/datamodel.py:326: UserWarning:
#
# No 'URL' and 'Commit' specified. This model might not be re-usable.
# Fitting michaelis-menten
# Fitting competitive product inhibition
# Fitting substrate inhibition
# <style type="text/css">
# #T_da48f_row0_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_da48f_row1_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_da48f_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_da48f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da48f_level0_col0" class="col_heading level0 col0" >AIC</th>
#       <th id="T_da48f_level0_col1" class="col_heading level0 col1" >k_cat</th>
#       <th id="T_da48f_level0_col2" class="col_heading level0 col2" >K_m</th>
#       <th id="T_da48f_level0_col3" class="col_heading level0 col3" >K_ic</th>
#       <th id="T_da48f_level0_col4" class="col_heading level0 col4" >K_iu</th>
#       <th id="T_da48f_level0_col5" class="col_heading level0 col5" >k_ie</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_da48f_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_da48f_level1_col1" class="col_heading level1 col1" >1 / sec</th>
#       <th id="T_da48f_level1_col2" class="col_heading level1 col2" >mmol / l</th>
#       <th id="T_da48f_level1_col3" class="col_heading level1 col3" >mmol / l</th>
#       <th id="T_da48f_level1_col4" class="col_heading level1 col4" >mmol / l</th>
#       <th id="T_da48f_level1_col5" class="col_heading level1 col5" >1 / sec</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da48f_level0_row0" class="row_heading level0 row0" >substrate inhibition</th>
#       <td id="T_da48f_row0_col0" class="data row0 col0" >-13539</td>
#       <td id="T_da48f_row0_col1" class="data row0 col1" >0.02</td>
#       <td id="T_da48f_row0_col2" class="data row0 col2" >0.27</td>
#       <td id="T_da48f_row0_col3" class="data row0 col3" ></td>
#       <td id="T_da48f_row0_col4" class="data row0 col4" >4000.00</td>
#       <td id="T_da48f_row0_col5" class="data row0 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_da48f_level0_row1" class="row_heading level0 row1" >michaelis-menten</th>
#       <td id="T_da48f_row1_col0" class="data row1 col0" >-13538</td>
#       <td id="T_da48f_row1_col1" class="data row1 col1" >0.02</td>
#       <td id="T_da48f_row1_col2" class="data row1 col2" >0.26</td>
#       <td id="T_da48f_row1_col3" class="data row1 col3" ></td>
#       <td id="T_da48f_row1_col4" class="data row1 col4" ></td>
#       <td id="T_da48f_row1_col5" class="data row1 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_da48f_level0_row2" class="row_heading level0 row2" >competitive product inhibition</th>
#       <td id="T_da48f_row2_col0" class="data row2 col0" >-13536</td>
#       <td id="T_da48f_row2_col1" class="data row2 col1" >0.02</td>
#       <td id="T_da48f_row2_col2" class="data row2 col2" >0.26</td>
#       <td id="T_da48f_row2_col3" class="data row2 col3" >43.50</td>
#       <td id="T_da48f_row2_col4" class="data row2 col4" ></td>
#       <td id="T_da48f_row2_col5" class="data row2 col5" ></td>
#     </tr>
#   </tbody>
# </table>

# %%
# Visualize models
estimator.visualize()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.27.0.min.js"></script>                <div id="c2aaa311-e4e8-414a-9fda-a703fed43609" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2aaa311-e4e8-414a-9fda-a703fed43609")) {                    Plotly.newPlot(                        "c2aaa311-e4e8-414a-9fda-a703fed43609",                        [{"customdata":["measured"],"hovertemplate":"Well ID: A1","marker":{"color":"rgba(99, 110, 250, 255)"},"mode":"markers","name":"0.0 mmol L\u003csup\u003e-1\u003c\u002fsup\u003e","showlegend":true,"x":[0.0,49.0,97.0,146.0,194.0,242.0,291.0,340.0,388.0,436.0,485.0,533.0,581.0,630.0,679.0,727.0,776.0,824.0,872.0,928.0],"y":[-0.003152777777777778,-0.002784722222222222,-0.002451388888888889,-0.002326388888888889,-0.0021874999999999998,-0.002097222222222222,-0.0019097222222222222,-0.001798611111111111,-0.001701388888888889,-0.0016944444444444446,-0.0016805555555555554,-0.0017916666666666667,-0.0018055555555555555,-0.00175,-0.0017569444444444444,-0.0017916666666666667,-0.0018333333333333333,-0.0018125,-0.001798611111111111,-0.001875],"type":"scatter"},{"customdata":["measured"],"hovertemplate":"Well ID: B1","marker":{"color":"rgba(99, 110, 250, 255)"},"mode":"markers","name":"0.0 mmol L\u003csup\u003e-1\u003c\u002fsup\u003e","showlegend":false,"x":[0.0,49.0,97.0,146.0,194.0,242.0,291.0,340.0,388.0,436.0,485.0,533.0,581.0,630.0,679.0,727.0,776.0,824.0,872.0,928.0],"y":[-0.002784722222222222,-0.002173611111111111,-0.001923611111111111,-0.001611111111111111,-0.001548611111111111,-0.001576388888888889,-0.001340277777777778,-0.001284722222222222,-0.0010277777777777778,-0.0009722222222222222,-0.0009583333333333333,-0.001,-0.0011041666666666667,-0.0008958333333333333,-0.0009305555555555556,-0.0009375,-0.0009652777777777777,-0.0008888888888888889,-0.0008125,-0.0009097222222222222],"type":"scatter"},{"customdata":["measured"],"hovertemplate":"Well ID: C1","marker":{"color":"rgba(99, 110, 250, 255)"},"mode":"markers","name":"0.0 mmol L\u003csup\u003e-1\u003c\u002fsup\u003e","showlegend":false,"x":[0.0,49.0,97.0,146.0,194.0,242.0,291.0,340.0,388.0,436.0,485.0,533.0,581.0,630.0,679.0,727.0,776.0,824.0,872.0,928.0],"y":[-0.002958333333333333,-0.003388888888888889,-0.0034861111111111113,-0.0034444444444444444,-0.0034861111111111113,-0.0037777777777777775,-0.003597222222222222,-0.0036805555555555554,-0.0034652777777777776,-0.003513888888888889,-0.0036666666666666666,-0.0036666666666666666,-0.0038541666666666668,-0.003631944444444444,-0.0038055555555555555,-0.003798611111111111,-0.003895833333333333,-0.0038611111111111107,-0.003833333333333333,-0.003833333333333333],"type":"scatter"},{"customdata":["measured"],"hovertemplate":"Well ID: D1","marker":{"color":"rgba(99, 110, 250, 255)"},"mode":"markers","name":"0.0 mmol L\u003csup\u003e-1\u003c\u002fsup\u003e","showlegend":false,"x":[0.0,49.0,97.0,146.0,194.0,242.0,291.0,340.0,388.0,436.0,485.0,533.0,581.0,630.0,679.0,727.0,776.0,824.0,872.0,928.0],"y":[-0.004395833333333333,-0.004520833333333333,-0.004402777777777777,-0.004291666666666667,-0.004395833333333333,-0.004347222222222222,-0.004263888888888889,-0.004527777777777777,-0.004270833333333333,-0.004347222222222222,-0.004298611111111111,-0.004381944444444444,-0.004458333333333332,-0.0042499999999999994,-0.0042499999999999994,-0.004416666666666667,-0.004340277777777778,-0.0043749999999999995,-0.004291666666666667,-0.004284722222222222],"type":"scatter"},{"customdata":["measured"],"hovertemplate":"Well ID: A2","marker":{"color":"rgba(239, 85, 59, 255)"},"mode":"markers","name":"0.3 mmol L\u003csup\u003e-1\u003c\u002fsup\u003e","showlegend":true,"x":[0.0,49.0,97.0,146.0,194.0,242.0,291.0,340.0,388.0,436.0,485.0,533.0,581.0,630.0,679.0,727.0,776.0,824.0,872.0,928.0],"y":[0.0009791666666666666,0.00411 ...

# %% [markdown]
# ## Save modeling results to EnzymeML

# %%
# Get the reaction system
reaction_system = estimator.get_reaction_system("michaelis-menten")

# Save the reaction system to EnzymeML
result_doc = estimator.to_enzymeml(enzymeml=enzymeml, reaction_system=reaction_system)

# %%
print(enzymeml)
# Out:
# EnzymeMLDocument
# ├── id = enzymemldocument0
# ├── name = laccase kinetic assay
# ├── created = 2023-10-30 22:54:54.406960
# ├── vessels
# │   └── 0
# │       └── Vessel
# │           ├── id = plate0
# │           ├── name = MTP 96 well
# │           ├── volume = 200.0
# │           ├── unit = ul
# │           └── constant = True
# ├── proteins
# │   └── 0
# │       └── Protein
# │           ├── id = p0
# │           ├── name = Laccase
# │           ├── vessel_id = plate0
# │           ├── constant = True
# │           ├── sequence = MSSKSKPKDVKV
# │           └── ontology = SBO:0000013
# ├── reactants
# │   ├── 0
# │   │   └── Reactant
# │   │       ├── id = s0
# │   │       ├── name = Buffer
# │   │       ├── vessel_id = plate0
# │   │       ├── constant = True
# │   │       └── ontology = SBO:0000247
# │   ├── 1
# │   │   └── Reactant
# │   │       ├── id = s1
# │   │       ├── name = ABTS
# │   │       ├── vessel_id = plate0
# │   │       ├── constant = False
# │   │       └── ontology = SBO:0000247
# │   └── 2
# │       └── Reactant
# │           ├── id = s2
# │           ├── name = ABTS radical
# │           ├── vessel_id = plate0
# │           ├── constant = False
# │           └── ontology = SBO:0000247
# ├── reactions
# │   └── 0
# │       └── Reaction
# │           ├── id = r1
# │           ├── name = Oxidation
# │           ├── reversible = False
# │           ├── temperature = 36.9
# │           ├── temperature_unit = C
# │           ├── ph = 3.0
# │           ├── ontology = SBO:0000176
# │           ├── model
# │           │   └── KineticModel
# │           │       ├── id = model1
# │           │       ├── name = michaelis-menten
# │           │       ├── equation = substrate = -substrate * enzyme * k_cat / (K_m + substrate)
# │           │       └── parameters
# │           │           ├── 0
# │           │           │   └── KineticParameter
# │           │           │       ├── id = kineticparameter0
# │           │           │       ├── name = K_m
# │           │           │       ├── value = 0.26142543066150725
# │           │           │       ├── unit = mmol / l
# │           │           │       ├── initial_value = 40.0
# │           │           │       ├── upper = 40000.0
# │           │           │       ├── lower = 0.04
# │           │           │       ├── is_global = False
# │           │           │       ├── stdev = 0.004639904967072504
# │           │           │       ├── constant = False
# │           │           │       └── ontology = SBO:0000027
# │           │           └── 1
# │           │               └── KineticParameter
# │           │                   ├── id = kineticparameter1
# │           │                   ├── name = k_cat
# │           │                   ├── value = 0.021441563629093705
# │           │                   ├── unit = 1 / sec
# │           │                   ├── initial_value = 0.029875578703708605
# │           │                   ├── upper = 29.875578703708605
# │           │                   ├── lower = 2.9875578703708605e-05
# │           │                   ├── is_global = False
# │           │                   ├── stdev = 6.366104639301951e-05
# │           │                   ├── constant = False
# │           │                   └── ontology = SBO:0000025
# │           ├── educts
# │           │   └── 0
# │           │       └── ReactionElement
# │           │           ├── id = reactionelement0
# │           │           ├── species_id = s1
# │           │           ├── stoichiometry = 1.0
# │           │           ├── constant = False
# │           │           └── ontology = SBO:0000015
# │           ├── products
# │           │   └── 0
# │           │       └── ReactionElement
# │           │           ├── id = reactionelement1
# │           │           ├── species_id = s2
# │           │           ├── stoichiometry = 1.0
# │           │           ├── constant = False
# │           │           └── ontology = SBO:0000011
# │           └── modifiers
# │               └── 0
# │                   └── ReactionElement
# │                       ├── id = reactionelement2
# │                       ├── species_id = p0
# │                       ├── stoichiometry = 1.0
# │                       ├── constant = True
# │                       └── ontology = SBO:0000013
# └── measurements
#     ├── 0
#     │   └── Measurement
#     │       ├── id = measurement0
#     │       ├── name = ABTS radical measurement
#     │       ├── temperature = 36.9
#     │       ├── temperature_unit = C
#     │       ├── ph = 3.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata0
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement0
#     │       │   │       └── species_id = s0
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata1
#     │       │   │       ├── init_conc = 0.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement0
#     │       │   │       └── species_id = s1
#     │       │   ├── 2
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata2
#     │       │   │       ├── init_conc = 0.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement0
#     │       │   │       ├── species_id = s2
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A1
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement0
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [-0.003152777777777778, -0.002784722222222222, -0.002451388888888889, -0.002326388888888889, -0.0021874999999999998, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B1
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement0
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [-0.002784722222222222, -0.002173611111111111, -0.001923611111111111, -0.001611111111111111, -0.001548611111111111, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 2
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = C1
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement0
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [-0.002958333333333333, -0.003388888888888889, -0.0034861111111111113, -0.0034444444444444444, -0.0034861111111111113, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 3
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = D1
#     │       │   │                   ├── species_id = s2
#     │       │   │                   ├── measurement_id = measurement0
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = sec
#     │       │   │                   ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │                   ├── data = [-0.004395833333333333, -0.004520833333333333, -0.004402777777777777, -0.004291666666666667, -0.004395833333333333, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 3
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata3
#     │       │           ├── init_conc = 0.006
#     │       │           ├── unit = mmol / l
#     │       │           ├── measurement_id = measurement0
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       └── global_time_unit = sec
#     ├── 1
#     │   └── Measurement
#     │       ├── id = measurement1
#     │       ├── name = ABTS radical measurement
#     │       ├── temperature = 36.9
#     │       ├── temperature_unit = C
#     │       ├── ph = 3.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata4
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement1
#     │       │   │       └── species_id = s0
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata5
#     │       │   │       ├── init_conc = 0.3
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement1
#     │       │   │       └── species_id = s1
#     │       │   ├── 2
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata6
#     │       │   │       ├── init_conc = 0.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement1
#     │       │   │       ├── species_id = s2
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A2
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement1
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0009791666666666666, 0.004111111111111111, 0.0069166666666666664, 0.009986111111111112, 0.01325, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B2
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement1
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0007708333333333333, 0.004006944444444444, 0.0067847222222222215, 0.00986111111111111, 0.013187500000000001, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 2
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = C2
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement1
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.001284722222222222, 0.003965277777777778, 0.0069375, 0.010041666666666667, 0.013270833333333332, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 3
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = D2
#     │       │   │                   ├── species_id = s2
#     │       │   │                   ├── measurement_id = measurement1
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = sec
#     │       │   │                   ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │                   ├── data = [0.0016388888888888887, 0.004277777777777778, 0.0073125, 0.010284722222222223, 0.013076388888888887, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 3
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata7
#     │       │           ├── init_conc = 0.006
#     │       │           ├── unit = mmol / l
#     │       │           ├── measurement_id = measurement1
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       └── global_time_unit = sec
#     ├── 2
#     │   └── Measurement
#     │       ├── id = measurement2
#     │       ├── name = ABTS radical measurement
#     │       ├── temperature = 36.9
#     │       ├── temperature_unit = C
#     │       ├── ph = 3.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata8
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement2
#     │       │   │       └── species_id = s0
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata9
#     │       │   │       ├── init_conc = 0.6
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement2
#     │       │   │       └── species_id = s1
#     │       │   ├── 2
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata10
#     │       │   │       ├── init_conc = 0.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement2
#     │       │   │       ├── species_id = s2
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A3
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement2
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0017430555555555556, 0.0047152777777777774, 0.007513888888888889, 0.010840277777777777, 0.014298611111111111, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B3
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement2
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0023888888888888887, 0.005534722222222221, 0.008652777777777778, 0.012013888888888888, 0.015625, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 2
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = C3
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement2
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0020416666666666665, 0.005145833333333333, 0.008548611111111111, 0.012201388888888888, 0.015805555555555555, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 3
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = D3
#     │       │   │                   ├── species_id = s2
#     │       │   │                   ├── measurement_id = measurement2
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = sec
#     │       │   │                   ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │                   ├── data = [0.0017638888888888888, 0.005229166666666667, 0.008437499999999999, 0.011881944444444445, 0.015465277777777777, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 3
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata11
#     │       │           ├── init_conc = 0.006
#     │       │           ├── unit = mmol / l
#     │       │           ├── measurement_id = measurement2
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       └── global_time_unit = sec
#     ├── 3
#     │   └── Measurement
#     │       ├── id = measurement3
#     │       ├── name = ABTS radical measurement
#     │       ├── temperature = 36.9
#     │       ├── temperature_unit = C
#     │       ├── ph = 3.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata12
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement3
#     │       │   │       └── species_id = s0
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata13
#     │       │   │       ├── init_conc = 0.9
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement3
#     │       │   │       └── species_id = s1
#     │       │   ├── 2
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata14
#     │       │   │       ├── init_conc = 0.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement3
#     │       │   │       ├── species_id = s2
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A4
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement3
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0018611111111111111, 0.004972222222222222, 0.008284722222222223, 0.011763888888888888, 0.015541666666666665, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B4
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement3
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0017638888888888888, 0.0050625, 0.008395833333333333, 0.012006944444444443, 0.01584722222222222, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 2
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = C4
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement3
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0019166666666666666, 0.0051875, 0.0085625, 0.0119375, 0.01579861111111111, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 3
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = D4
#     │       │   │                   ├── species_id = s2
#     │       │   │                   ├── measurement_id = measurement3
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = sec
#     │       │   │                   ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │                   ├── data = [0.0027916666666666667, 0.005888888888888889, 0.009305555555555556, 0.012902777777777777, 0.016666666666666666, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 3
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata15
#     │       │           ├── init_conc = 0.006
#     │       │           ├── unit = mmol / l
#     │       │           ├── measurement_id = measurement3
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       └── global_time_unit = sec
#     ├── 4
#     │   └── Measurement
#     │       ├── id = measurement4
#     │       ├── name = ABTS radical measurement
#     │       ├── temperature = 36.9
#     │       ├── temperature_unit = C
#     │       ├── ph = 3.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata16
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement4
#     │       │   │       └── species_id = s0
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata17
#     │       │   │       ├── init_conc = 5.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement4
#     │       │   │       └── species_id = s1
#     │       │   ├── 2
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata18
#     │       │   │       ├── init_conc = 0.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement4
#     │       │   │       ├── species_id = s2
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A5
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement4
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.005131944444444444, 0.008798611111111111, 0.012756944444444444, 0.017076388888888887, 0.021687500000000002, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B5
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement4
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.005388888888888889, 0.009152777777777777, 0.01313888888888889, 0.017534722222222222, 0.022159722222222223, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 2
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = C5
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement4
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.005840277777777778, 0.009729166666666667, 0.013777777777777778, 0.018229166666666668, 0.022986111111111113, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 3
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = D5
#     │       │   │                   ├── species_id = s2
#     │       │   │                   ├── measurement_id = measurement4
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = sec
#     │       │   │                   ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │                   ├── data = [0.006, 0.009875, 0.014083333333333333, 0.01851388888888889, 0.023381944444444445, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 3
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata19
#     │       │           ├── init_conc = 0.006
#     │       │           ├── unit = mmol / l
#     │       │           ├── measurement_id = measurement4
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       └── global_time_unit = sec
#     ├── 5
#     │   └── Measurement
#     │       ├── id = measurement5
#     │       ├── name = ABTS radical measurement
#     │       ├── temperature = 36.9
#     │       ├── temperature_unit = C
#     │       ├── ph = 3.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata20
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement5
#     │       │   │       └── species_id = s0
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata21
#     │       │   │       ├── init_conc = 30.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement5
#     │       │   │       └── species_id = s1
#     │       │   ├── 2
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata22
#     │       │   │       ├── init_conc = 0.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement5
#     │       │   │       ├── species_id = s2
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A7
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement5
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.02684027777777778, 0.030756944444444444, 0.03565972222222222, 0.04095138888888889, 0.04680555555555556, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B7
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement5
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.02759722222222222, 0.03154166666666666, 0.03634722222222222, 0.041673611111111106, 0.0474375, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 2
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = C7
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement5
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.027624999999999997, 0.03151388888888889, 0.03620138888888889, 0.04142361111111111, 0.04713194444444444, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 3
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = D7
#     │       │   │                   ├── species_id = s2
#     │       │   │                   ├── measurement_id = measurement5
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = sec
#     │       │   │                   ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │                   ├── data = [0.02701388888888889, 0.031166666666666665, 0.03592361111111111, 0.04129861111111111, 0.04720138888888888, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 3
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata23
#     │       │           ├── init_conc = 0.006
#     │       │           ├── unit = mmol / l
#     │       │           ├── measurement_id = measurement5
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       └── global_time_unit = sec
#     ├── 6
#     │   └── Measurement
#     │       ├── id = measurement6
#     │       ├── name = ABTS radical measurement
#     │       ├── temperature = 36.9
#     │       ├── temperature_unit = C
#     │       ├── ph = 3.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata24
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement6
#     │       │   │       └── species_id = s0
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata25
#     │       │   │       ├── init_conc = 50.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement6
#     │       │   │       └── species_id = s1
#     │       │   ├── 2
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata26
#     │       │   │       ├── init_conc = 0.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement6
#     │       │   │       ├── species_id = s2
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A8
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement6
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0436875, 0.04750694444444445, 0.05222916666666667, 0.05759027777777778, 0.06353472222222223, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B8
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement6
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.04322916666666667, 0.04710416666666667, 0.05168055555555555, 0.056937499999999995, 0.06277083333333333, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 2
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = C8
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement6
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.04413194444444444, 0.04793055555555556, 0.052548611111111115, 0.057763888888888885, 0.06338194444444444, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 3
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = D8
#     │       │   │                   ├── species_id = s2
#     │       │   │                   ├── measurement_id = measurement6
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = sec
#     │       │   │                   ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │                   ├── data = [0.04309027777777778, 0.04699305555555555, 0.051500000000000004, 0.056680555555555553, 0.06240277777777777, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 3
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata27
#     │       │           ├── init_conc = 0.006
#     │       │           ├── unit = mmol / l
#     │       │           ├── measurement_id = measurement6
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       └── global_time_unit = sec
#     ├── 7
#     │   └── Measurement
#     │       ├── id = measurement7
#     │       ├── name = ABTS radical measurement
#     │       ├── temperature = 36.9
#     │       ├── temperature_unit = C
#     │       ├── ph = 3.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata28
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement7
#     │       │   │       └── species_id = s0
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata29
#     │       │   │       ├── init_conc = 70.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement7
#     │       │   │       └── species_id = s1
#     │       │   ├── 2
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata30
#     │       │   │       ├── init_conc = 0.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement7
#     │       │   │       ├── species_id = s2
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A9
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement7
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.06099305555555555, 0.0644861111111111, 0.06904166666666667, 0.07421527777777777, 0.0799375, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B9
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement7
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.06156944444444445, 0.06495833333333333, 0.06925694444444444, 0.07436111111111111, 0.07979861111111111, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 2
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = C9
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement7
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.06231944444444444, 0.06550694444444445, 0.06980555555555557, 0.07493055555555556, 0.08043055555555555, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 3
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = D9
#     │       │   │                   ├── species_id = s2
#     │       │   │                   ├── measurement_id = measurement7
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = sec
#     │       │   │                   ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │                   ├── data = [0.06166666666666667, 0.06521527777777777, 0.06955555555555555, 0.07466666666666666, 0.08009722222222222, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 3
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata31
#     │       │           ├── init_conc = 0.006
#     │       │           ├── unit = mmol / l
#     │       │           ├── measurement_id = measurement7
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       └── global_time_unit = sec
#     ├── 8
#     │   └── Measurement
#     │       ├── id = measurement8
#     │       ├── name = ABTS radical measurement
#     │       ├── temperature = 36.9
#     │       ├── temperature_unit = C
#     │       ├── ph = 3.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata32
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement8
#     │       │   │       └── species_id = s0
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata33
#     │       │   │       ├── init_conc = 0.15
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement8
#     │       │   │       └── species_id = s1
#     │       │   ├── 2
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata34
#     │       │   │       ├── init_conc = 0.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement8
#     │       │   │       ├── species_id = s2
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = E1
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement8
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0017708333333333332, 0.0040486111111111105, 0.006152777777777778, 0.008548611111111111, 0.011069444444444443, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = F1
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement8
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0012916666666666664, 0.0034652777777777776, 0.005833333333333334, 0.0083125, 0.010861111111111111, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 2
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = G1
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement8
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0027291666666666666, 0.004159722222222223, 0.006416666666666666, 0.008798611111111111, 0.011194444444444444, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 3
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = H1
#     │       │   │                   ├── species_id = s2
#     │       │   │                   ├── measurement_id = measurement8
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = sec
#     │       │   │                   ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │                   ├── data = [0.0006388888888888888, 0.002763888888888889, 0.005270833333333333, 0.007826388888888888, 0.010416666666666666, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 3
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata35
#     │       │           ├── init_conc = 0.006
#     │       │           ├── unit = mmol / l
#     │       │           ├── measurement_id = measurement8
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       └── global_time_unit = sec
#     ├── 9
#     │   └── Measurement
#     │       ├── id = measurement9
#     │       ├── name = ABTS radical measurement
#     │       ├── temperature = 36.9
#     │       ├── temperature_unit = C
#     │       ├── ph = 3.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata36
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement9
#     │       │   │       └── species_id = s0
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata37
#     │       │   │       ├── init_conc = 0.45
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement9
#     │       │   │       └── species_id = s1
#     │       │   ├── 2
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata38
#     │       │   │       ├── init_conc = 0.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement9
#     │       │   │       ├── species_id = s2
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = E2
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement9
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0031388888888888885, 0.006333333333333333, 0.009791666666666666, 0.013222222222222222, 0.016777777777777777, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = F2
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement9
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0034930555555555552, 0.0065069444444444445, 0.009916666666666667, 0.01342361111111111, 0.01675, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 2
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = G2
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement9
#     │       │   │           │       ├── data_type = abs
# ...
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.012381944444444444, 0.017090277777777777, 0.021625000000000002, 0.026715277777777775, 0.03238194444444444, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 2
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = G5
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement12
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.012673611111111111, 0.016909722222222222, 0.021645833333333333, 0.0269375, 0.03246527777777778, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 3
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = H5
#     │       │   │                   ├── species_id = s2
#     │       │   │                   ├── measurement_id = measurement12
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = sec
#     │       │   │                   ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │                   ├── data = [0.013256944444444443, 0.01792361111111111, 0.023215277777777776, 0.028868055555555557, 0.034993055555555555, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 3
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata51
#     │       │           ├── init_conc = 0.006
#     │       │           ├── unit = mmol / l
#     │       │           ├── measurement_id = measurement12
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       └── global_time_unit = sec
#     ├── 13
#     │   └── Measurement
#     │       ├── id = measurement13
#     │       ├── name = ABTS radical measurement
#     │       ├── temperature = 36.9
#     │       ├── temperature_unit = C
#     │       ├── ph = 3.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata52
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement13
#     │       │   │       └── species_id = s0
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata53
#     │       │   │       ├── init_conc = 40.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement13
#     │       │   │       └── species_id = s1
#     │       │   ├── 2
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata54
#     │       │   │       ├── init_conc = 0.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement13
#     │       │   │       ├── species_id = s2
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = E7
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement13
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.03765972222222222, 0.041715277777777775, 0.04664583333333333, 0.05211111111111111, 0.057951388888888886, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = F7
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement13
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.03779861111111111, 0.042131944444444444, 0.04725694444444444, 0.052833333333333336, 0.05875, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 2
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = G7
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement13
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.03772222222222222, 0.042312499999999996, 0.04751388888888889, 0.05331944444444445, 0.05945833333333333, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 3
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = H7
#     │       │   │                   ├── species_id = s2
#     │       │   │                   ├── measurement_id = measurement13
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = sec
#     │       │   │                   ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │                   ├── data = [0.03835416666666667, 0.043055555555555555, 0.04841666666666667, 0.05440972222222222, 0.0608125, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 3
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata55
#     │       │           ├── init_conc = 0.006
#     │       │           ├── unit = mmol / l
#     │       │           ├── measurement_id = measurement13
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       └── global_time_unit = sec
#     ├── 14
#     │   └── Measurement
#     │       ├── id = measurement14
#     │       ├── name = ABTS radical measurement
#     │       ├── temperature = 36.9
#     │       ├── temperature_unit = C
#     │       ├── ph = 3.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata56
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement14
#     │       │   │       └── species_id = s0
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata57
#     │       │   │       ├── init_conc = 60.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement14
#     │       │   │       └── species_id = s1
#     │       │   ├── 2
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata58
#     │       │   │       ├── init_conc = 0.0
#     │       │   │       ├── unit = mmol / l
#     │       │   │       ├── measurement_id = measurement14
#     │       │   │       ├── species_id = s2
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = E8
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement14
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.05245833333333333, 0.056520833333333326, 0.06119444444444444, 0.06645138888888888, 0.07215972222222221, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = F8
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement14
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.05267361111111111, 0.0566875, 0.06134722222222222, 0.06672222222222222, 0.07236111111111111, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 2
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = G8
#     │       │   │           │       ├── species_id = s2
#     │       │   │           │       ├── measurement_id = measurement14
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = sec
#     │       │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │           │       ├── data = [0.0538125, 0.058062499999999996, 0.06302083333333333, 0.06843055555555556, 0.07422916666666667, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 3
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = H8
#     │       │   │                   ├── species_id = s2
#     │       │   │                   ├── measurement_id = measurement14
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = sec
#     │       │   │                   ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       │   │                   ├── data = [0.0541875, 0.058319444444444445, 0.0633125, 0.06886111111111111, 0.07485416666666667, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 3
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata59
#     │       │           ├── init_conc = 0.006
#     │       │           ├── unit = mmol / l
#     │       │           ├── measurement_id = measurement14
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#     │       └── global_time_unit = sec
#     └── 15
#         └── Measurement
#             ├── id = measurement15
#             ├── name = ABTS radical measurement
#             ├── temperature = 36.9
#             ├── temperature_unit = C
#             ├── ph = 3.0
#             ├── species
#             │   ├── 0
#             │   │   └── MeasurementData
#             │   │       ├── id = measurementdata60
#             │   │       ├── init_conc = 100.0
#             │   │       ├── unit = mmol / l
#             │   │       ├── measurement_id = measurement15
#             │   │       └── species_id = s0
#             │   ├── 1
#             │   │   └── MeasurementData
#             │   │       ├── id = measurementdata61
#             │   │       ├── init_conc = 80.0
#             │   │       ├── unit = mmol / l
#             │   │       ├── measurement_id = measurement15
#             │   │       └── species_id = s1
#             │   ├── 2
#             │   │   └── MeasurementData
#             │   │       ├── id = measurementdata62
#             │   │       ├── init_conc = 0.0
#             │   │       ├── unit = mmol / l
#             │   │       ├── measurement_id = measurement15
#             │   │       ├── species_id = s2
#             │   │       └── replicates
#             │   │           ├── 0
#             │   │           │   └── Replicate
#             │   │           │       ├── id = E9
#             │   │           │       ├── species_id = s2
#             │   │           │       ├── measurement_id = measurement15
#             │   │           │       ├── data_type = abs
#             │   │           │       ├── data_unit = dimensionless
#             │   │           │       ├── time_unit = sec
#             │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#             │   │           │       ├── data = [0.07011805555555556, 0.07373611111111111, 0.07826388888888888, 0.08334722222222221, 0.08877083333333333, ...]
#             │   │           │       └── is_calculated = False
#             │   │           ├── 1
#             │   │           │   └── Replicate
#             │   │           │       ├── id = F9
#             │   │           │       ├── species_id = s2
#             │   │           │       ├── measurement_id = measurement15
#             │   │           │       ├── data_type = abs
#             │   │           │       ├── data_unit = dimensionless
#             │   │           │       ├── time_unit = sec
#             │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#             │   │           │       ├── data = [0.07147916666666668, 0.07503472222222222, 0.07936805555555555, 0.08447916666666666, 0.09004166666666666, ...]
#             │   │           │       └── is_calculated = False
#             │   │           ├── 2
#             │   │           │   └── Replicate
#             │   │           │       ├── id = G9
#             │   │           │       ├── species_id = s2
#             │   │           │       ├── measurement_id = measurement15
#             │   │           │       ├── data_type = abs
#             │   │           │       ├── data_unit = dimensionless
#             │   │           │       ├── time_unit = sec
#             │   │           │       ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#             │   │           │       ├── data = [0.0700763888888889, 0.0741111111111111, 0.07881944444444444, 0.08428472222222222, 0.09016666666666666, ...]
#             │   │           │       └── is_calculated = False
#             │   │           └── 3
#             │   │               └── Replicate
#             │   │                   ├── id = H9
#             │   │                   ├── species_id = s2
#             │   │                   ├── measurement_id = measurement15
#             │   │                   ├── data_type = abs
#             │   │                   ├── data_unit = dimensionless
#             │   │                   ├── time_unit = sec
#             │   │                   ├── time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#             │   │                   ├── data = [0.06953472222222222, 0.07370833333333332, 0.07874999999999999, 0.08439583333333334, 0.09054166666666667, ...]
#             │   │                   └── is_calculated = False
#             │   └── 3
#             │       └── MeasurementData
#             │           ├── id = measurementdata63
#             │           ├── init_conc = 0.006
#             │           ├── unit = mmol / l
#             │           ├── measurement_id = measurement15
#             │           └── species_id = p0
#             ├── global_time = [0.0, 49.0, 97.0, 146.0, 194.0, ...]
#             └── global_time_unit = sec
